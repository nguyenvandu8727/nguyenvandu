# %%
hall=11.25
kit=18.0
liv=20.0
bed=10.75
bath=9.50
areas = [hall, kit, liv, bed, bath]
print(areas)
# Out:
# [11.25, 18.0, 20.0, 10.75, 9.5]

# %%
hall=11.25
kit=18.0
liv=20.0
bed=10.75
bath=9.50
areas = [hall, kit, "livingroom", bed, "bathroom"]

# %%
house =[["hallway", hall],
        ["kitchen", kit],
        ["livingroom", liv],
        ["bathroom", bath]]

print(house)
print(type(house))
# Out:
# [['hallway', 11.25], ['kitchen', 18.0], ['livingroom', 20.0], ['bathroom', 9.5]]
# <class 'list'>

# %%
areas = ["hallway", 11.25, "kitchen", 18., "livingroom", 20.0, "badroom", 10.75, "bathroom", 9.50]
         
print(areas[1])
print(areas[-1])
print(areas[5])
# Out:
# 11.25
# 9.5
# 20.0

# %%
areas = ["hallway", 11.25, "kitchen", 18.0, "livingroom", 20.0, "bedroom", 10.75, "bathroom", 9.50]
eat_sleep_area = areas[3] + areas[-3]
print(eat_sleep_area)
# Out:
# 28.75

# %%
areas = ["hallway", 11.25, "kitchen", 18.0, "livingroom", 20.0, "bedroom", 10.75, "bathroom", 9.50]
downstairs = areas[0:6]
upstairs = areas[6:-1]
print(downstairs)
print(upstairs)
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'livingroom', 20.0]
# ['bedroom', 10.75, 'bathroom']

# %%
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]
downstairs = areas[:6]
upstairs = areas[6:]
print(downstairs)
print(upstairs)
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'living room', 20.0]
# ['bedroom', 10.75, 'bathroom', 9.5]

# %%
x = [["a", "b", "c"],
     ["d", "e", "f"],
     ["g", "h", "i"]]
x[2][0]
x[2][:2]
# Out:
# ['g', 'h']
